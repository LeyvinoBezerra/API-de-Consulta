# %% [markdown]
# <a href="https://colab.research.google.com/github/LeyvinoBezerra/API-de-Consulta/blob/main/Aula_2_2_Introdu%C3%A7%C3%A3o_ao_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Documentação do Pandas
# https://pandas.pydata.org/pandas-docs/stable/index.html

# %% [markdown]
# ## 1 - Montagem do Drive

# %%
#monte o drive caso precise usar/salvar arquivos do seu drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#mude o ponto de execução para outro diretório, caso deseje
# %cd /content/drive/MyDrive/Colab Notebooks/AprendizadoMaquina
# Out:
# /content/drive/MyDrive/Colab Notebooks/AprendizadoMaquina

# %% [markdown]
# importando a Biblioteca e lendo o Dataset

# %%
import pandas as pd

# %%
#leitura do dataset no meu drive
df = pd.read_csv('fake_data_2.csv')

# %%
#OU coloca direto o endereço do csv (nesse caso, nem precisaria montar o drive)
df = pd.read_csv('https://raw.githubusercontent.com/CaiqueCoelho/Preprocessing-Dataset-Template/master/fake_data_2.csv')

# %%
#visão do dataset
df
# Out:
#           cargo  idade  salario    bonus sócio
# 0       Diretor     45  24000.0  10000.0   sim
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 3       Gerente     24  15100.0      NaN   não
# 4       Gerente     30  35000.0   6000.0   sim
# 5   Programador     22   5300.0   2000.0   não
# 6      Analista     20      NaN   1200.0   não
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %% [markdown]
# ## 2- Visão Geral do Dataset
#
#
# [Dataset retirado daqui](https://github.com/CaiqueCoelho/Preprocessing-Dataset-Template)

# %% [markdown]
# ### Trabalhando com dataframes

# %%
df.head(3)
# Out:
#          cargo  idade  salario    bonus sócio
# 0      Diretor     45  24000.0  10000.0   sim
# 1     Analista     22   8000.0   2000.0   não
# 2  Programador     30      NaN   1000.0   não

# %%
df.tail()
# Out:
#           cargo  idade  salario    bonus sócio
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
#Apresenta as colunas do Dataset
df.columns
# Out:
# Index(['cargo', 'idade', 'salario', 'bonus', 'sócio'], dtype='object')

# %%
#fazendo referencia a uma coluna específica
df['salario']
# Out:
# 0     24000.0
# 1      8000.0
# 2         NaN
# 3     15100.0
# 4     35000.0
# 5      5300.0
# 6         NaN
# 7     18000.0
# 8     38000.0
# 9      7300.0
# 10     2344.0
# 11     4500.0
# 12    30000.0
# 13    14000.0
# Name: salario, dtype: float64

# %%
#mostrando as linhas de 0 a 3.
df[0:4]
# Out:
#          cargo  idade  salario    bonus sócio
# 0      Diretor     45  24000.0  10000.0   sim
# 1     Analista     22   8000.0   2000.0   não
# 2  Programador     30      NaN   1000.0   não
# 3      Gerente     24  15100.0      NaN   não

# %%
#fazendo referencia a algumas colunas
df[['cargo', 'idade']] #dois colchetes nesse caso
# Out:
#           cargo  idade
# 0       Diretor     45
# 1      Analista     22
# 2   Programador     30
# 3       Gerente     24
# 4       Gerente     30
# 5   Programador     22
# 6      Analista     20
# 7       Diretor     50
# 8      Fundador     65
# 9      Analista     32
# 10  Programador     35
# 11  Programador     28
# 12     Fundador     28
# 13  Programador     30

# %%
#apresenta os valores unicos da coluna selecionada
df['cargo'].unique()
# Out:
# array(['Diretor', 'Analista', 'Programador', 'Gerente', 'Fundador'],
#       dtype=object)

# %%
#Renomeando colunas
df.rename(columns={'sócio':'socio'})
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 3       Gerente     24  15100.0      NaN   não
# 4       Gerente     30  35000.0   6000.0   sim
# 5   Programador     22   5300.0   2000.0   não
# 6      Analista     20      NaN   1200.0   não
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
# A operação do rename não alterou o banco original. Nesse caso precisariamos guardar o resultado da operação em outra variável
df.head()
# Out:
#          cargo  idade  salario    bonus sócio
# 0      Diretor     45  24000.0  10000.0   sim
# 1     Analista     22   8000.0   2000.0   não
# 2  Programador     30      NaN   1000.0   não
# 3      Gerente     24  15100.0      NaN   não
# 4      Gerente     30  35000.0   6000.0   sim

# %%
# Para que a alteração seja realizada no dataframe original, precisamos o parâmetro inplace
df.rename(columns={'sócio':'socio'}, inplace = True)
df.head()
# Out:
#          cargo  idade  salario    bonus socio
# 0      Diretor     45  24000.0  10000.0   sim
# 1     Analista     22   8000.0   2000.0   não
# 2  Programador     30      NaN   1000.0   não
# 3      Gerente     24  15100.0      NaN   não
# 4      Gerente     30  35000.0   6000.0   sim

# %%
#verifica os tipos e valores faltosos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cargo    14 non-null     object
#  1   idade    14 non-null     int64
#  2   salario  12 non-null     float64
#  3   bonus    12 non-null     float64
#  4   socio    14 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 692.0+ bytes

# %%
# Verifica os valores faltosos
df.isna()
# Out:
#     cargo  idade  salario  bonus  socio
# 0   False  False    False  False  False
# 1   False  False    False  False  False
# 2   False  False     True  False  False
# 3   False  False    False   True  False
# 4   False  False    False  False  False
# 5   False  False    False  False  False
# 6   False  False     True  False  False
# 7   False  False    False  False  False
# 8   False  False    False  False  False
# 9   False  False    False  False  False
# 10  False  False    False   True  False
# 11  False  False    False  False  False
# 12  False  False    False  False  False
# 13  False  False    False  False  False

# %%
#sumariza os valores faltosos por coluna/atributo
df.isna().sum()
# Out:
# cargo      0
# idade      0
# salario    2
# bonus      2
# socio      0
# dtype: int64

# %%
#verifica informações gerais sobre colunas numéricas
df.describe()
# Out:
#            idade       salario         bonus
# count  14.000000     12.000000     12.000000
# mean   32.928571  16795.333333   7200.000000
# std    12.499011  12355.108162   7610.996829
# min    20.000000   2344.000000   1000.000000
# 25%    25.000000   6800.000000   2000.000000
# 50%    30.000000  14550.000000   5000.000000
# 75%    34.250000  25500.000000  10000.000000
# max    65.000000  38000.000000  28000.000000

# %% [markdown]
# **loc**
#
# Pode-se usar o método loc para localizar linhas ou pedaços do dataframe pelos rótulos
#
# Sintaxe:
#
# loc[linhas, colunas]
#
# Onde as linhas e colunas podem ser passadas em sequencia (:) ou saltos (,)

# %%
df.loc[0, 'cargo'] #um elemento
# Out:
# 'Diretor'

# %%
df.loc[0:3] #uma sequencia de linhas
# Out:
#          cargo  idade  salario    bonus socio
# 0      Diretor     45  24000.0  10000.0   sim
# 1     Analista     22   8000.0   2000.0   não
# 2  Programador     30      NaN   1000.0   não
# 3      Gerente     24  15100.0      NaN   não

# %%
df.loc[0:3, 'cargo':'salario'] #pedaço do dataframe, usando sequencia de linhas e colunas
# Out:
#          cargo  idade  salario
# 0      Diretor     45  24000.0
# 1     Analista     22   8000.0
# 2  Programador     30      NaN
# 3      Gerente     24  15100.0

# %%
df.loc[[0,3], ['cargo', 'salario']] #pedaço do dataframe, usando linhas e colunas em saltos (observar colchetes)
# Out:
#      cargo  salario
# 0  Diretor  24000.0
# 3  Gerente  15100.0

# %%
#como pegar duas sequências diferentes:

pd.concat([df.loc[0:3], df.loc[10:12]])

#pode usar o concat do pandas que irá concatenar dois dataframes (ou pedaços de dataframes)
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 3       Gerente     24  15100.0      NaN   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim

# %% [markdown]
# **iloc**
#
# Pode-se usar o método iloc para localizar linhas ou pedaços do dataframe pelos índices numéricos (posicionais)
#
# Sintaxe (igual a do loc):
#
# iloc[linhas, colunas]
#
# Onde as linhas e colunas podem usar sequencias (:) ou saltos (,)
#
# A diferença de iloc para loc é que loc usa os rotulos, enquanto iloc usa os indices numericos default

# %%
df.iloc[0, 0] #um elemento (linha 0, coluna cargo)
# Out:
# 'Diretor'

# %%
df.iloc[0:3, 0:3] #sequencia
# Out:
#          cargo  idade  salario
# 0      Diretor     45  24000.0
# 1     Analista     22   8000.0
# 2  Programador     30      NaN

# %%
df.iloc[[0,3], [0,3]] #salto
# Out:
#      cargo    bonus
# 0  Diretor  10000.0
# 3  Gerente      NaN

# %% [markdown]
# ###Filtros no Data Frame

# %% [markdown]
# #### 1 - Diretamente nas colunas

# %%
df['idade']>25
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# Name: idade, dtype: bool

# %%
#Filtrando valores em uma coluna especifica
df[df['idade']>25]
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 2   Programador     30      NaN   1000.0   não
# 4       Gerente     30  35000.0   6000.0   sim
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
# guardando o resultado do filtro em outra variavel
df_idade = df[df['idade']>25]
print(df_idade)
# apresentando o formato da variavel
df_idade.shape
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 2   Programador     30      NaN   1000.0   não
# 4       Gerente     30  35000.0   6000.0   sim
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim
# (10, 5)

# %%
(df['idade']>25) & (df['salario']>7000)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12     True
# 13     True
# dtype: bool

# %%
df[(df['idade']>25) & (df['salario']>7000)]
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 4       Gerente     30  35000.0   6000.0   sim
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %% [markdown]
# #### 2 - Usando o método query

# %%
#Outra forma de filtrar dados no Dataset é por meio do método query
df.query('idade >25')
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 2   Programador     30      NaN   1000.0   não
# 4       Gerente     30  35000.0   6000.0   sim
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
df.query('idade >25 & salario>7000')
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 4       Gerente     30  35000.0   6000.0   sim
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 12     Fundador     28  30000.0  12000.0   sim
# 13  Programador     30  14000.0  10000.0   sim

# %%
# usando uma variavel como parametro na query
idade_mediana = df['idade'].median()
print(idade_mediana)
# Out:
# 30.0

# %%
df.query('idade>@idade_mediana')
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 7       Diretor     50  18000.0   8000.0   sim
# 8      Fundador     65  38000.0  28000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não

# %%
#query com string
df.query('cargo == "Diretor"')
# Out:
#      cargo  idade  salario    bonus socio
# 0  Diretor     45  24000.0  10000.0   sim
# 7  Diretor     50  18000.0   8000.0   sim

# %%
# o metodo isin seleciona os registros que atendem aos itens listados
df[df['cargo'].isin(['Analista','Programador','Diretor'])]
# Out:
#           cargo  idade  salario    bonus socio
# 0       Diretor     45  24000.0  10000.0   sim
# 1      Analista     22   8000.0   2000.0   não
# 2   Programador     30      NaN   1000.0   não
# 5   Programador     22   5300.0   2000.0   não
# 6      Analista     20      NaN   1200.0   não
# 7       Diretor     50  18000.0   8000.0   sim
# 9      Analista     32   7300.0   4000.0   não
# 10  Programador     35   2344.0      NaN   não
# 11  Programador     28   4500.0   2200.0   não
# 13  Programador     30  14000.0  10000.0   sim

# %% [markdown]
# #### 3 - Utilizando o método filter

# %%
df.filter(['cargo','idade','salario'])
# Out:
#           cargo  idade  salario
# 0       Diretor     45  24000.0
# 1      Analista     22   8000.0
# 2   Programador     30      NaN
# 3       Gerente     24  15100.0
# 4       Gerente     30  35000.0
# 5   Programador     22   5300.0
# 6      Analista     20      NaN
# 7       Diretor     50  18000.0
# 8      Fundador     65  38000.0
# 9      Analista     32   7300.0
# 10  Programador     35   2344.0
# 11  Programador     28   4500.0
# 12     Fundador     28  30000.0
# 13  Programador     30  14000.0

# %% [markdown]
# ### Métodos úteis
# Value_counts
#
# retorna uma série contendo contagens de valores únicos. O objeto resultante estará em ordem decrescente para que o primeiro elemento seja o elemento que ocorre com mais frequência. Exclui valores NA por padrão.

# %%
#apresenta a quantidade de valores unicos para uma coluna em particular
df['socio'].value_counts()
# Out:
# socio
# não    8
# sim    6
# Name: count, dtype: int64

# %%
#Para atributos numéricos podemos usar o parametro bins
df['salario'].value_counts(bins=4)
# Out:
# (2308.343, 11258.0]    5
# (11258.0, 20172.0]     3
# (29086.0, 38000.0]     3
# (20172.0, 29086.0]     1
# Name: count, dtype: int64

# %%
#apresenta a quantidade de valores em cada coluna
df.count()
# Out:
# cargo      14
# idade      14
# salario    12
# bonus      12
# socio      14
# dtype: int64

# %%
df['cargo'].count()
# Out:
# np.int64(14)

# %% [markdown]
# Groupby

# %%
obj = df.groupby('cargo')
obj

# %%
#apresentando os itens de cada grupo formado
obj.groups
# Out:
# {'Analista': [1, 6, 9], 'Diretor': [0, 7], 'Fundador': [8, 12], 'Gerente': [3, 4], 'Programador': [2, 5, 10, 11, 13]}

# %%
obj.get_group('Gerente')
# Out:
#      cargo  idade  salario   bonus socio
# 3  Gerente     24  15100.0     NaN   não
# 4  Gerente     30  35000.0  6000.0   sim

# %%
df.groupby('cargo').count()
# Out:
#              idade  salario  bonus  socio
# cargo
# Analista         3        2      3      3
# Diretor          2        2      2      2
# Fundador         2        2      2      2
# Gerente          2        2      1      2
# Programador      5        4      4      5

# %%
# experimente usar count
df.groupby('cargo')['idade'].count()
# Out:
# cargo
# Analista       3
# Diretor        2
# Fundador       2
# Gerente        2
# Programador    5
# Name: idade, dtype: int64

# %%
#experimente calcular a media e a mediana do agrupamemto
df.groupby('cargo')['salario'].sum()
# Out:
# cargo
# Analista       15300.0
# Diretor        42000.0
# Fundador       68000.0
# Gerente        50100.0
# Programador    26144.0
# Name: salario, dtype: float64

# %% [markdown]
# ####AGREGANDO INFORMAÇÕES NO GROUPBY

# %%
import numpy as np

# %%
obj2 = df.groupby('cargo')[['idade','salario','bonus']]

# %%
obj2.agg([np.mean,np.median])
# Out:
# /tmp/ipython-input-3625622659.py:1: FutureWarning: The provided callable <function mean at 0x7a1906519c60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   obj2.agg([np.mean,np.median])
# /tmp/ipython-input-3625622659.py:1: FutureWarning: The provided callable <function median at 0x7a190646df80> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   obj2.agg([np.mean,np.median])
# /tmp/ipython-input-3625622659.py:1: FutureWarning: The provided callable <function mean at 0x7a1906519c60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   obj2.agg([np.mean,np.median])
# ...

# %%
obj2.mean().sort_values(by='salario',ascending=True)
# Out:
#                  idade  salario    bonus
# cargo
# Programador  29.000000   6536.0   3800.0
# Analista     24.666667   7650.0   2400.0
# Diretor      47.500000  21000.0   9000.0
# Gerente      27.000000  25050.0   6000.0
# Fundador     46.500000  34000.0  20000.0

# %%
df.groupby(['cargo','socio']).count()
# Out:
#                    idade  salario  bonus
# cargo       socio
# Analista    não        3        2      3
# Diretor     sim        2        2      2
# Fundador    sim        2        2      2
# Gerente     não        1        1      0
#             sim        1        1      1
# Programador não        4        3      3
#             sim        1        1      1

# %%
df.groupby(['cargo','socio']).agg(media_salario =('salario',np.mean),mediana_idade=('idade',np.median))
# Out:
# /tmp/ipython-input-4187732503.py:1: FutureWarning: The provided callable <function mean at 0x7a1906519c60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(['cargo','socio']).agg(media_salario =('salario',np.mean),mediana_idade=('idade',np.median))
# /tmp/ipython-input-4187732503.py:1: FutureWarning: The provided callable <function median at 0x7a190646df80> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby(['cargo','socio']).agg(media_salario =('salario',np.mean),mediana_idade=('idade',np.median))
#                    media_salario  mediana_idade
# cargo       socio
# Analista    não           7650.0           22.0
# Diretor     sim          21000.0           47.5
# ...

# %%
#estatistica basica da idade de cada cargo
df.groupby('cargo')['idade'].describe()
# Out:
#              count       mean        std   min    25%   50%    75%   max
# cargo
# Analista       3.0  24.666667   6.429101  20.0  21.00  22.0  27.00  32.0
# Diretor        2.0  47.500000   3.535534  45.0  46.25  47.5  48.75  50.0
# Fundador       2.0  46.500000  26.162951  28.0  37.25  46.5  55.75  65.0
# Gerente        2.0  27.000000   4.242641  24.0  25.50  27.0  28.50  30.0
# Programador    5.0  29.000000   4.690416  22.0  28.00  30.0  30.00  35.0
